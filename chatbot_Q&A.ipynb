# %%
# !pip install --upgrade pip 
# !pip install --upgrade langchain 
# !pip install --upgrade langchain-community 
# !pip install --upgrade langchain-text-splitters 
# !pip install --upgrade langchain-aws 
# !pip install --upgrade faiss-cpu==1.7.4
# !pip install --upgrade pypdf 
# !pip install --upgrade boto3
# Out:
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (26.2)
# Collecting pip
#   Downloading pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.2.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 97.0 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.2
#     Uninstalling pip-26.2:
#       Successfully uninstalled pip-26.2
# Successfully installed pip-26.2.1
# Collecting langchain
#   Downloading langchain-1.4.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-core<2.0.0,>=1.6.0 (from langchain)
#   Downloading langchain_core-1.6.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting langgraph<1.3.0,>=1.2.11 (from langchain)
#   Downloading langgraph-1.2.11-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain) (2.13.4)
# Collecting httpx<1.0.0,>=0.23.0 (from langchain-core<2.0.0,>=1.6.0->langchain)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading langchain_protocol-0.0.19-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading langsmith-0.12.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.6.0->langchain)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading uuid_utils-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: anyio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.14.2)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Collecting httpcore==1.* (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain)
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading langgraph_checkpoint-4.2.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading langgraph_sdk-0.4.4-py3-none-any.whl.metadata (5.1 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading xxhash-4.0.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (17 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading ormsgpack-1.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading orjson-3.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting websockets<17,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain)
#   Downloading websockets-16.1.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.8 kB)
# Collecting distro>=1.7.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx2<3,>=2 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading httpx2-2.12.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.34.2)
# Collecting sniffio>=1.1 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain)
#   Using cached zstandard-0.25.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.3 kB)
# Collecting httpcore2==2.12.0 (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading httpcore2-2.12.0-py3-none-any.whl.metadata (25 kB)
# Collecting truststore>=0.10 (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain)
#   Downloading truststore-0.10.4-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.7.0)
# Downloading langchain-1.4.0-py3-none-any.whl (161 kB)
# Downloading langchain_core-1.6.2-py3-none-any.whl (571 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.7/571.7 kB 34.2 MB/s  0:00:00
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.2.11-py3-none-any.whl (248 kB)
# Downloading langgraph_checkpoint-4.2.0-py3-none-any.whl (56 kB)
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.4.4-py3-none-any.whl (162 kB)
# Downloading langsmith-0.12.2-py3-none-any.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.7/760.7 kB 51.1 MB/s  0:00:00
# Downloading httpx2-2.12.0-py3-none-any.whl (95 kB)
# Downloading httpcore2-2.12.0-py3-none-any.whl (83 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
# Downloading websockets-16.1.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (186 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Downloading langchain_protocol-0.0.19-py3-none-any.whl (7.3 kB)
# Downloading orjson-3.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
# Downloading ormsgpack-1.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading truststore-0.10.4-py3-none-any.whl (18 kB)
# Downloading xxhash-4.0.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (249 kB)
# Using cached zstandard-0.25.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.6 MB)
# Installing collected packages: zstandard, xxhash, websockets, uuid-utils, truststore, tenacity, sniffio, ormsgpack, orjson, langchain-protocol, jsonpointer, httpcore, distro, requests-toolbelt, jsonpatch, httpcore2, httpx2, httpx, langsmith, langchain-core, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25/25 [langchain]25 [langgraph]sdk]]
# Successfully installed distro-1.9.0 httpcore-1.0.9 httpcore2-2.12.0 httpx-0.28.1 httpx2-2.12.0 jsonpatch-1.33 jsonpointer-3.1.1 langchain-1.4.0 langchain-core-1.6.2 langchain-protocol-0.0.19 langgraph-1.2.11 langgraph-checkpoint-4.2.0 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.4 langsmith-0.12.2 orjson-3.12.0 ormsgpack-1.12.2 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 truststore-0.10.4 uuid-utils-0.17.0 websockets-16.1.1 xxhash-4.0.1 zstandard-0.25.0
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Using cached aiohttp-3.14.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.3 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-community) (1.6.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-community) (0.12.2)
# Requirement already satisfied: numpy>=1.26.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-community) (2.34.2)
# Collecting sqlalchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Using cached sqlalchemy-2.0.52-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-community) (9.1.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached propcache-0.5.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: typing_extensions>=4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.16.0)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached yarl-1.24.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (103 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (24.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: anyio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (4.14.2)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.0.9)
# Requirement already satisfied: idna in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (0.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.4.4)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Using cached python_dotenv-1.2.3-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.7.0)
# Collecting greenlet>=1 (from sqlalchemy<3.0.0,>=1.4.0->langchain-community)
#   Using cached greenlet-3.5.5-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.3.1)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 125.1 MB/s  0:00:00
# Using cached aiohttp-3.14.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 81.8 MB/s  0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (243 kB)
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
# Using cached sqlalchemy-2.0.52-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
# Using cached yarl-1.24.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (110 kB)
# Using cached aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
# Downloading greenlet-3.5.5-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (622 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 39.1 MB/s  0:00:00
# Using cached propcache-0.5.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (60 kB)
# Using cached python_dotenv-1.2.3-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, propcache, multidict, httpx-sse, greenlet, frozenlist, async-timeout, aiohappyeyeballs, yarl, sqlalchemy, aiosignal, pydantic-settings, aiohttp, langchain-text-splitters, langchain-classic, langchain-community
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [langchain-community]ngchain-community]
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 async-timeout-4.0.3 frozenlist-1.8.0 greenlet-3.5.5 httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-text-splitters-1.1.2 multidict-6.7.1 propcache-0.5.2 pydantic-settings-2.15.0 python-dotenv-1.2.3 sqlalchemy-2.0.52 yarl-1.24.5
# Requirement already satisfied: langchain-text-splitters in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-text-splitters) (1.6.2)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.12.2)
# Requirement already satisfied: packaging>=23.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.17.0)
# Requirement already satisfied: anyio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.14.2)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.7.0)
# Collecting langchain-aws
#   Downloading langchain_aws-1.7.5-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: boto3>=1.43.64 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-aws) (1.43.79)
# Requirement already satisfied: langchain-core>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-aws) (1.6.2)
# Requirement already satisfied: numpy<3,>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-aws) (2.2.6)
# Requirement already satisfied: pydantic<3,>=2.10.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-aws) (2.13.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=2.10.6->langchain-aws) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=2.10.6->langchain-aws) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=2.10.6->langchain-aws) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=2.10.6->langchain-aws) (0.4.4)
# Requirement already satisfied: botocore<1.44.0,>=1.43.79 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.43.64->langchain-aws) (1.43.79)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.43.64->langchain-aws) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.43.64->langchain-aws) (0.19.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.44.0,>=1.43.79->boto3>=1.43.64->langchain-aws) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.44.0,>=1.43.79->boto3>=1.43.64->langchain-aws) (2.7.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.79->boto3>=1.43.64->langchain-aws) (1.17.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core>=1.6.0->langchain-aws) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core>=1.6.0->langchain-aws) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core>=1.6.0->langchain-aws) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core>=1.6.0->langchain-aws) (0.12.2)
# Requirement already satisfied: packaging>=23.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core>=1.6.0->langchain-aws) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core>=1.6.0->langchain-aws) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core>=1.6.0->langchain-aws) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langchain-core>=1.6.0->langchain-aws) (0.17.0)
# Requirement already satisfied: anyio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=1.6.0->langchain-aws) (4.14.2)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=1.6.0->langchain-aws) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=1.6.0->langchain-aws) (1.0.9)
# Requirement already satisfied: idna in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=1.6.0->langchain-aws) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core>=1.6.0->langchain-aws) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=1.6.0->langchain-aws) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (0.10.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio->httpx<1.0.0,>=0.23.0->langchain-core>=1.6.0->langchain-aws) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=1.6.0->langchain-aws) (3.4.9)
# Downloading langchain_aws-1.7.5-py3-none-any.whl (234 kB)
# Installing collected packages: langchain-aws
# Successfully installed langchain-aws-1.7.5
# Collecting faiss-cpu==1.7.4
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 124.8 MB/s  0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.7.4
# Collecting pypdf
#   Downloading pypdf-6.17.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pypdf) (4.16.0)
# Downloading pypdf-6.17.0-py3-none-any.whl (388 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-6.17.0
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.43.79)
# Collecting boto3
#   Downloading boto3-1.43.89-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<1.44.0,>=1.43.89 (from boto3)
#   Downloading botocore-1.43.89-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3) (0.19.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.44.0,>=1.43.89->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.44.0,>=1.43.89->boto3) (2.7.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.89->boto3) (1.17.0)
# Downloading boto3-1.43.89-py3-none-any.whl (140 kB)
# Downloading botocore-1.43.89-py3-none-any.whl (15.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 169.2 MB/s  0:00:00
# Installing collected packages: botocore, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.43.79
#     Uninstalling botocore-1.43.79:
#       Successfully uninstalled botocore-1.43.79
#   Attempting uninstall: boto3━━━━━━━━━━━━━━━━━━━ 0/2 [botocore]
#     Found existing installation: boto3 1.43.790m 0/2 [botocore]
#     Uninstalling boto3-1.43.79:━━━━━━━━━━━━━ 0/2 [botocore]
#       Successfully uninstalled boto3-1.43.79 0/2 [botocore]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [boto3]
# Successfully installed boto3-1.43.89 botocore-1.43.89

# %%
import boto3 
from langchain_community.document_loaders import PyPDFLoader 
from langchain_text_splitters import RecursiveCharacterTextSplitter 
from langchain_community.vectorstores import FAISS 
from langchain_aws import BedrockEmbeddings, ChatBedrock

# %%
import boto3 
def read_s3_pdf(bucket, key, local_file="document.pdf"): 
    s3 = boto3.client('s3') 
    s3.download_file(bucket, key, local_file) 
    return local_file

# %%
bucket = "whiz-bucket0071" 
key = "document.pdf" 
local_path = read_s3_pdf(bucket, key) 
print(f"Downloaded file to: {local_path}")
# Out:
# Downloaded file to: document.pdf

# %%
from langchain_aws import ChatBedrock, BedrockEmbeddings 
from langchain_community.vectorstores import FAISS 
from langchain_community.document_loaders import PyPDFLoader 
from langchain_text_splitters import RecursiveCharacterTextSplitter 
# Load PDF and split 
loader = PyPDFLoader("document.pdf") 
pages = loader.load() 
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50) 
docs = splitter.split_documents(pages)

# %%
from langchain_aws import ChatBedrock 
llm = ChatBedrock(
    model_id="amazon.nova-lite-v1:0", 
    region_name="us-east-1" )

# %%
# query = "What is Lorem Ipsum?" 
query = "What is Lorem Ipsum?" 
answer = llm.invoke( 
    f"Answer the following question clearly:\\n\\nQuestion: {query}" 
) 
print(answer.content)
# Out:
# Lorem Ipsum is a type of placeholder text commonly used in the publishing and typesetting industry. It is derived from a scrambled section of "De Finibus Bonorum et Malorum," a treatise written by the Roman philosopher Cicero in 45 BC. The text is used to demonstrate the elements of a typographic layout or visual presentation without relying on meaningful content. It typically appears as:
#
# ```
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# ```
#
# Because it is nonsensical, it helps designers focus on the layout and design without being distracted by the meaning of the words.
